-- %% [markdown]
-- # [dbo].[Roles]

-- %%
USE [ShopDb]
GO

-- %%
INSERT [dbo].[Roles] ([Id], [Name]) VALUES (N'75a56e64-1c4f-44cf-af56-63b79b8879bc', N'admin')
INSERT [dbo].[Roles] ([Id], [Name]) VALUES (N'5c1f1413-1d45-40c0-920a-92277ec4e0b1', N'user')
GO

-- %% [markdown]
-- # [dbo].[Payments]

-- %%
INSERT [dbo].[Payments] ([Id], [PaymentType], [CardNumber], [ExpirationDate], [SecurityCode], [FirstName], [LastName], [City], [BillingAdress], [ZipPostalCode], [Country], [PhoneNumber]) VALUES (N'55e0049c-daf9-4b0c-88b6-86f8a68a2d7a', 1, N'111', CAST(N'2023-05-05' AS Date), N'11', N'Dimitar', N'Kotevski', N'aaa', N'aaaa', N'aaaa', N'aaa', N'aaa')
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
INSERT [dbo].[Users] ([Id], [Username], [Password], [FirstName], [LastName], [Description], [Email], [City], [State], [ZipCode], [Address], [PaymentId], [Amount], [RoleId]) VALUES (N'3c4c1cf3-4ca6-4acc-8072-b05d00ecad37', N'dimitarkotevski1', N'7i8WHfjwUko0NBM8wshjFcJuAXUkqngB2KRik70aM9A=', N'Dimitar', N'Kotevski', NULL, N'dimitardimitar@gmail.com', NULL, NULL, NULL, NULL, NULL, 0, N'5c1f1413-1d45-40c0-920a-92277ec4e0b1')
INSERT [dbo].[Users] ([Id], [Username], [Password], [FirstName], [LastName], [Description], [Email], [City], [State], [ZipCode], [Address], [PaymentId], [Amount], [RoleId]) VALUES (N'3ab8cad9-f132-46f6-a4d6-b05e016125ef', N'admin', N'pIbvhgmpVHahDBTYUgQvew==', N'a', N'a', NULL, N'admin@gmail.com', NULL, NULL, NULL, NULL, NULL, 0, N'75a56e64-1c4f-44cf-af56-63b79b8879bc')
INSERT [dbo].[Users] ([Id], [Username], [Password], [FirstName], [LastName], [Description], [Email], [City], [State], [ZipCode], [Address], [PaymentId], [Amount], [RoleId]) VALUES (N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'dimitarkotevski', N'7i8WHfjwUko0NBM8wshjFcJuAXUkqngB2KRik70aM9A=', N'Dimitar', N'Kotevski', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam. Donec vehicula dictum quam, at pretium nisl gravida sed. Sed varius bibendum ligula, sed scelerisque odio. Morbi odio nibh, vulputate quis eleifend in, eleifend id dui. Nulla scelerisque sem orci, vel finibus ante dapibus pellentesque. Vivamus ultrices volutpat leo, eleifend rutrum dui auctor sit amet. Nunc vitae purus sed risus laoreet fringilla.', N'kotevski.dimitar15@gmail.com', N'Skopje', N'North Macedonia', N'7244', N'Pelisterska 5', NULL, 20000, N'5c1f1413-1d45-40c0-920a-92277ec4e0b1')
GO

-- %% [markdown]
-- # [dbo].[ShoppingCarts]

-- %%
INSERT [dbo].[ShoppingCarts] ([Id], [UserId], [Name], [Active]) VALUES (N'8922d672-5917-4166-901c-4e587e8e0317', N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'CART-22222', 1)
INSERT [dbo].[ShoppingCarts] ([Id], [UserId], [Name], [Active]) VALUES (N'91a83fb9-548a-4ed6-8ab9-b05d00ecba1b', N'3c4c1cf3-4ca6-4acc-8072-b05d00ecad37', N'CART-12312', 1)
INSERT [dbo].[ShoppingCarts] ([Id], [UserId], [Name], [Active]) VALUES (N'11871fc9-ab24-4ead-8491-b05e01612634', N'3ab8cad9-f132-46f6-a4d6-b05e016125ef', NULL, 1)
INSERT [dbo].[ShoppingCarts] ([Id], [UserId], [Name], [Active]) VALUES (N'709627da-562e-4f4a-89d9-cc7494d8bd38', N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'CART-12345', 0)
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'9cc5ec0b-9703-4858-92cc-afa900ac492d', N'Laptops, Computers and Servers', 1, N'laptops-computers-servers')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'a6de64ce-2eab-4862-8bd8-afb3008ebc86', N'Phones, Tablets and Navigation', 1, N'phones-tablets-navigation')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'71886b6d-1332-4a34-91e6-afb30095c072', N'TV, Audio and Cameras', 1, N'tv-audio-cameras')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'505681d2-f9b4-441f-895c-afb30095ecf4', N'Gaming', 1, N'gaming')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'913ffb5e-ecd0-4316-874a-afb300960dd6', N'Smart', 1, N'smart')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'767e453c-eb5b-4754-a1aa-afb30099a397', N'Computer parts', 1, N'computer-parts')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'119619bc-1a3c-4efe-b880-afb300a3ced4', N'Outlet', 1, N'outlet')
INSERT [dbo].[Categories] ([Id], [Name], [Status], [Url]) VALUES (N'1b4903c2-c084-46d8-aba0-afe200bbf311', N'Accessories', 1, N'accessories')
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'8a0b5f89-9005-458f-8180-056f48e0bb5f', N'Victus 15L HP TG02-0003nc', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 700, CAST(N'2023-07-16' AS Date), ..., N'#computer')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'a8c6f1ac-d11b-42cd-a448-158d26a45ac9', N'Logitech G403 wired mouse', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'767e453c-eb5b-4754-a1aa-afb30099a397', 100.2, CAST(N'2023-07-07' AS Date), ..., NULL)
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'a3c72740-3d17-45a7-9a7c-358dee8c2094', N'Samsung S23', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'a6de64ce-2eab-4862-8bd8-afb3008ebc86', 1200.2, CAST(N'2023-06-01' AS Date), ..., NULL)
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'd2ee9843-5716-42d0-ab21-440a43b30e0a', N'UPS-NG Eaton Ellipse PRO 850 FR', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 250, CAST(N'2023-07-16' AS Date), ..., N'#server')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'37e43970-1724-48bf-a0a7-7574f679359f', N'Lenovo IdeaCentre Gaming 5 14ACN6', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 12003131, CAST(N'2023-07-16' AS Date), ..., N'#computer')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'8e6dc15c-1584-4abd-ab74-9329309ffd77', N'CZC.Gaming Knight GC149', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 900, CAST(N'2023-07-16' AS Date), ..., N'#computer')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'560061b8-67a9-4221-837d-a97fc72bb1ee', N'Lenovo Legion 5 | 15.6"  | i7 12th Gen i7-12700H  | 16 GB  RAM | 2 TB SSD ', N'Lenovo Legion 5 | 15.6"  | i7 12th Gen i7-12700H  | 16GB  RAM | 2 TB SSD.
The Lenovo Legion 5 Pro has muscular mid-range specifications which include an Intel Core i7-13700HX processor with a total of 16 processor cores (eight Performance-cores and eight Efficient-cores) and a maximum clock speed of 5GHz. It''s paired with 16GB of DDR5 memory and a 512GB solid state drive', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 732.21, CAST(N'2023-07-16' AS Date), ..., N'#laptop')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'abda8f24-9ee8-413a-bdbf-afa900ac8655', N'Lenovo Legion Pro 5 | 16" |  i9 | 64GB |  2TB SSD |  RTX 4070 8GB ', N'Lenovo Legion Pro 5 | 16" |  i9 | 64GB RAM |  2TB SSD |  RTX 4070 8GB ', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 650.22, CAST(N'2023-06-06' AS Date), ..., N'#laptop  | 16" | 240Hz 24-Core 13th Intel Core i9-13900HX | 64GB | DDR5 2TB SSD | NVIDIA GEFORCE RTX 4070 8GB
')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'ef5b3fea-002a-4ca1-8ba2-afa900ac980a', N'Dell XPS 13 | 13.3" | i7-1165G7 | 16GB RAM | 512GB SSD', N'Dell XPS 13 9305 Laptop - 13.3-inch FHD (1920x1080) Display, Intel Core i7-1165G7, 16GB LPDDR4x RAM, 512GB SSD, Intel Iris Xe Graphics, Killer Wi-Fi 6 with Service, Windows 11 Home - Silver', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 1600.2, CAST(N'2023-03-25' AS Date), ..., N'#laptop')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'27804a95-06c2-452c-b437-afb800dae7b3', N'ASUS ZenBook Pro 15  15.6”  , AMD Ryzen 9  CPU,  RTX 3050 Ti , 16GB RAM, 1TB SSD', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 1000, CAST(N'2023-02-15' AS Date), ..., N'#laptop')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'd07eb6e8-98f6-418b-9623-afba008fa609', N'Acer Swift  | 14"  | AMD Ryzen 7 5700U Octa-Core Processor | 8GB RAM | 512GB SSD ', N'Acer Swift 3 SF314-42-R9YN comes with these high level specs: AMD Ryzen 7 4700U Octa-Core Mobile Processor 2. 0GHz with Precision Boost up to 4. 1GHz (Up to 8MB L3 Cache), Windows 10 Home, 14" Full HD Widescreen IPS LED-backlit Display 1920 x 1080 resolution; 16: 9 aspect ratio, AMD Radeon Graphics, 8GB LPDDR4 Onboard Memory, 512GB PCIe NVMe SSD, DTS Audio, featuring optimized bass response and micro-speaker distortion prevention, Two built-in front facing stereo speakers, Acer Purified. Voice technology with two built-in microphones, Intel Wireless Wi-Fi 6 AX200 802. 11ax Dual-Band 2. 4GHz and 5GHz featuring 2x2 MU-MIMO technology (Max Speed up to 2. 4Gbps), Bluetooth 5. 0, Back-lit Keyboard, Acer Bio-Protection Fingerprint Solution, featuring Computer Protection and Windows Hello Certification, HD Webcam (1280 x 720) supporting Super High Dynamic Range (SHDR), 1 - USB Type-C port USB 3. 2 Gen 2 (up to 10 Gbps) DisplayPort over USB Type-C & USB Charging, 1 - USB 3. 2 Gen 1 port (featuring power-off charging), 1 - USB 2. 0 port, 1 - HDMI port, Lithium-Ion Battery, Up to 11. 5-hours Battery Life, 2. 65 lbs. 1. 2 kg (system unit only) (NX. HSEAA. 003).', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 1235, CAST(N'2023-06-06' AS Date), ..., N'#laptop')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'c8d11a17-5663-458b-98d2-afba00ad7447', N'Acer Swift 3 
| 14" | AMD Ryzen 5 4500U | 256GB SSD', N'Acer Swift 3 Thin & Light Laptop, 14" Full HD IPS, AMD Ryzen 5 4500U Hexa-Core Processor with Radeon Graphics, 8GB LPDDR4, 256GB NVMe SSD, WiFi 6, Backlit Keyboard, Fingerprint Reader, SF314-42-R7LH', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 1125, CAST(N'2022-10-10' AS Date), ..., N'#laptop')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'35693716-8cc6-4d57-9fa9-e8c0244b8dd7', N'HP 24-cb0006nc', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 720.32, CAST(N'2023-07-16' AS Date), ..., N'#computer')
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'943e6425-ab5a-4064-9477-fd1ce2603cf4', N'Nikon D5500', N'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed lacinia semper dolor at semper. Sed quis dapibus metus. In dapibus eros bibendum sapien molestie mollis eu eu diam.', N'71886b6d-1332-4a34-91e6-afb30095c072', 1000, CAST(N'2023-08-08' AS Date), ..., NULL)
INSERT [dbo].[Products] ([Id], [Name], [Description], [CategoryId], [Price], [Created], [Image], [Tags]) VALUES (N'2ef1ff45-5257-4f98-adaf-ff8d2b78ba5d', N'ASUS ROG Strix G10DK', N'AMD Ryzen 7-3700X Processor 3.6 GHz (32M Cache, up to 4.4 GHz)
NVIDIA GeForce GTX 1660 Ti 6GB graphics
512GB PCIe NVMe M.2 SSD | 16GB DDR4 RAM | Windows 10 Home | Gigabit Wi-Fi 5 (802.11ac)
7.1 Virtual Surround front-panel audio with DTS:HeadphoneX
Customizable ASUS Aura Sync RGB chassis lighting | Transparent side panel included
Front I/O: 2x USB 3.2 Gen 1, 1x Headphone/Microphone
Rear I/O: 2x USB 3.2 Gen 2, 4x USB 3.2 Gen 1, 1x Mic, 1x Line Out, 1x Line In, 1x Ethernet, 1x HDMI-out
', N'9cc5ec0b-9703-4858-92cc-afa900ac492d', 2000, CAST(N'2023-07-16' AS Date), ..., N'#computer')
GO

-- %% [markdown]
-- # [dbo].[ShoppingCartDetails]

-- %%
INSERT [dbo].[ShoppingCartDetails] ([Id], [ShoppingCartId], [ProductId], [Quantity]) VALUES (N'e662c916-564d-4e2f-9a28-b055011938af', N'8922d672-5917-4166-901c-4e587e8e0317', N'943e6425-ab5a-4064-9477-fd1ce2603cf4', 1)
INSERT [dbo].[ShoppingCartDetails] ([Id], [ShoppingCartId], [ProductId], [Quantity]) VALUES (N'5bda646b-dfba-45f3-9af2-b05d00f0c4df', N'91a83fb9-548a-4ed6-8ab9-b05d00ecba1b', N'c8d11a17-5663-458b-98d2-afba00ad7447', 1)
GO

-- %% [markdown]
-- # [dbo].[Favourite]

-- %%
INSERT [dbo].[Favourite] ([Id], [UserId], [ProductId]) VALUES (N'9f2e3418-31eb-459a-8e92-290328f61774', N'3c4c1cf3-4ca6-4acc-8072-b05d00ecad37', N'd2ee9843-5716-42d0-ab21-440a43b30e0a')
INSERT [dbo].[Favourite] ([Id], [UserId], [ProductId]) VALUES (N'bd51ef94-5b49-41fb-aad5-57bcf9d04aa6', N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'c8d11a17-5663-458b-98d2-afba00ad7447')
INSERT [dbo].[Favourite] ([Id], [UserId], [ProductId]) VALUES (N'bd935c42-3217-4cba-8c31-72135dcea095', N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'943e6425-ab5a-4064-9477-fd1ce2603cf4')
INSERT [dbo].[Favourite] ([Id], [UserId], [ProductId]) VALUES (N'47ae2c57-1252-4bc6-9d87-773684a251c8', N'3c4c1cf3-4ca6-4acc-8072-b05d00ecad37', N'8a0b5f89-9005-458f-8180-056f48e0bb5f')
INSERT [dbo].[Favourite] ([Id], [UserId], [ProductId]) VALUES (N'9b59db52-a5c1-463f-9a82-95158f8034b7', N'3c4c1cf3-4ca6-4acc-8072-b05d00ecad37', N'37e43970-1724-48bf-a0a7-7574f679359f')
INSERT [dbo].[Favourite] ([Id], [UserId], [ProductId]) VALUES (N'4f0fdce0-a73d-4498-bd91-e88de4f333dd', N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'37e43970-1724-48bf-a0a7-7574f679359f')
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
INSERT [dbo].[Orders] ([Id], [OrderName], [UserId], [ShoppingCartId], [PaymentType], [OrderStatus], [TotalAmount], [DateCreated]) VALUES (N'b14a5b01-ab59-4372-b969-b05d00cd19cc', N'Order#11111', N'2e55cd2e-be62-4f0c-80af-eb262b097758', N'8922d672-5917-4166-901c-4e587e8e0317', 0, 1, CAST(1000 AS Decimal(38, 0)), CAST(N'2023-08-13T14:26:44.723' AS DateTime))
INSERT [dbo].[Orders] ([Id], [OrderName], [UserId], [ShoppingCartId], [PaymentType], [OrderStatus], [TotalAmount], [DateCreated]) VALUES (N'a39b93e8-16b1-474d-80fa-b05d00f5f489', N'Order#11111', N'3c4c1cf3-4ca6-4acc-8072-b05d00ecad37', N'91a83fb9-548a-4ed6-8ab9-b05d00ecba1b', 0, 1, CAST(1125 AS Decimal(38, 0)), CAST(N'2023-08-13T16:55:29.443' AS DateTime))
GO
